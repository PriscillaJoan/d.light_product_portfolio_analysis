# %%
import pandas as pd
import numpy as np

# %%
import sqlite3
conn = sqlite3.connect('dlight.db')
cursor=conn.cursor()

# %%
#load data
service_tickets = pd.read_csv('../data/bi_case_calls_combined.csv')
contracts = pd.read_csv('../data/bi_case_contracts_combined.csv')
payments = pd.read_csv('../data/bi_case_payments_combined.csv')
calls = pd.read_csv('../data/bi_case_calls_combined.csv')

# %%
#convert contracts to table
contracts.to_sql('contracts', conn, index=False, if_exists='replace')
# Out:
# 486623

# %%
# clean contract columns
contracts.columns = (
        contracts.columns
          .str.strip()
          .str.lower()
          .str.replace(' ', '_')
          .str.replace(r'[^\w]', '', regex=True)
    )

# %%
#look at datatypes
contracts.dtypes
# Out:
# contractid             int64
# sales_month           object
# region                object
# product               object
# sales_person_id      float64
# contract_type         object
# price_usd            float64
# payment_frequency     object
# perc_deposit         float64
# tenor_length         float64
# daily_amount_usd     float64
# customer_gender       object
# household_size        object
# occupation            object
# dtype: object

# %%
contracts.isna().sum()
# Out:
# contractid                0
# sales_month               0
# region                    0
# product                2166
# sales_person_id        9720
# contract_type             0
# price_usd              4561
# payment_frequency     25341
# perc_deposit          25352
# tenor_length          25341
# daily_amount_usd      29080
# customer_gender           0
# household_size       476253
# occupation            59683
# dtype: int64

# %%
contracts['household_size'].notna().sum()
# Out:
# 10370

# %%
# standardize contract id
contracts.rename({'contractid' : 'contract_id'}, inplace= True)

# %%
# convert sales_month to date
pd.to_datetime(contracts['sales_month'],format="%Y-%m-%d")
# Out:
# 0        2024-10-31
# 1        2025-04-30
# 2        2024-03-31
# 3        2024-05-31
# 4        2025-06-30
#             ...
# 486618   2025-09-30
# 486619   2025-09-30
# 486620   2025-09-30
# 486621   2025-09-30
# 486622   2025-09-30
# Name: sales_month, Length: 486623, dtype: datetime64[ns]

# %%
# convert house hold size to int
#contracts['household_size'] = contracts['household_size'].astype('Int64')

# %%
# take a close look at the household column
"""It appears that household size has mixed data and contains names and contacts"""

household = """SELECT household_size
                FROM contracts
                WHERE household_size IS NOT NULL"""
pd.read_sql(household, conn)
# Out:
#                                 household_size
# 0                                            4
# 1                                            3
# 2                                            4
# 3                                            6
# 4                                            3
# ...                                        ...
# 10365           256746372749 timwesige Jackson
# 10366                                        3
# 10367                256764718509 Nigesa marry
# 10368              256705097664 Nabbanja Annet
# 10369  256760335303  Mukasa  Bonifasi Abubaker
#
# [10370 rows x 1 columns]

# %%
#strip white spaces
col = 'household_size'
contracts[col] = contracts[col].astype(str).str.strip()

# %%
"""after physcially accessing the contracts csv file,it appears household sizes range from
1 to 9 members, so i'll isolate the actual household sizes to their own separate rows """

contracts['actual_household_size'] = contracts[col].where(contracts[col].str.match(r'^[1-9]$')).astype('Int64')

# %%
# have a closer look at the column
contracts['actual_household_size'].unique()
# Out:
# <IntegerArray>
# [<NA>, 4, 3, 6, 1, 7, 8, 5, 2, 9]
# Length: 10, dtype: Int64

# %%
"""create a boolean filter to separate names from phone numbers """
# Filters actual household sizes from mixed datatypes that contains names and contacts
mask_household_size = contracts['household_size'].str.match(r'^\d{1,2}$')

# filters for rows with actual household sizes and false for mixed datatypes(names+contacts)
mask_phone_name = ~mask_household_size

# %%
#create a phone number column
"""The regex \d{9,15} ensures that only numbers with 9-15 digits are considered.
 This is to avoid single digits like household sizes from being matched as phone numbers """

contracts.loc[mask_phone_name, 'phone_number'] = contracts.loc[mask_phone_name, 'household_size'].str.extract(r'^(\d{9,15})')[0]

# %%
# have a closer look at the phone number column
contracts['phone_number'].unique()
# Out:
# array([nan, '256776921622', '256751507695', ..., '256764718509',
#        '256705097664', '256760335303'], dtype=object)

# %%
# Extract names
contracts.loc[mask_phone_name, 'name'] = contracts.loc[mask_phone_name, 'household_size'].str.extract(r'^\d{9,15}\s+(.+)$')[0]

# %%
contracts['name'].unique()
# Out:
# array([nan, 'Erias Matovu', 'UPAKRWOTH  DANIEL', ..., 'Nigesa marry',
#        'Nabbanja Annet', 'Mukasa  Bonifasi Abubaker'], dtype=object)

# %%
# standardize names
contracts['name'] = contracts['name'].str.title()

# %%
"""Values that  meet exceptions for household size, phone number and names"""
counts_updates = (
    contracts['actual_household_size'].notna() |
    contracts['phone_number'].notna() |
    contracts['name'].notna()
)

counts_updates.sum()
# Out:
# 9989

# %%
"""Since householdsize had been converted to string type, null values will be replaced with nan. So ensure
we properly fill in the null values"""

contracts['household_size'] = contracts['household_size'].replace(["", "nan", None], np.nan)

# %%
unclassified = contracts[
    contracts['household_size'].notna() & ~counts_updates][['household_size']]

unclassified.sample(40)
# Out:
#                                household_size
# 102314           Nakyanzi Rose   256751370487
# 33390         TUMWEHEIRE SYLIVIA 256707342184
# 342030           Nangobi Besi\t  256780693951
# 194897             Kabeta Fatuma 256705730756
# 285704                                     02
# 341148                                     03
# 16155                                      11
# 30186                                      10
# 52068                  776-582-132 Leiya Edea
# 100165           256  Christine    Batahurira
# 424295        Patience Natukunda 256702158029
# 474027                          WARDI  JUSTUS
# 97880               Isooba Amuli 256755025852
# 32199                                      12
# 98616                                      03
# 378308                                     10
# 284025                                     03
# 422996              Kasiime Rose 256764571085
# 165192                                     13
# 98646                              Opio Robin
# 225673             Mugisa Joseph 256783930958
# 311766            Baliluno Peter 256784664502
# 425540                         Alal Josephine
# 347157         Flujensio Luswata 256777060586
# 435100                      Moreen Kyaligonza
# 282349                           Amolo Nighty
# 166488                                     20
# 330993  (+256)  755-685-798 Jeremiah Tusibira
# 189913         Zubedah Ndibogeza 256783169908
# 98620                                      02
# 341146                                     02
# 389816                                     10
# 9709                                       20
# 438003               Muduwa Jane 256745649941
# 38131         Irumba Mubaraka\t  256745970429
# 178221            kebba sabino\t 256743898812
# 171428           760-474-989 Asobasi Emmanuel
# 330199         NAMUSIMBI EVERLYN 256785745122
# 135004                                     10
# 247870                                     17

# %% [markdown]
# It appears that some households have two-digit members. Additionally, several phone numbers and names were not correctly extracted because some numbers contain special characters, and in certain cases, the entries start with names instead of numbers.

# %% [markdown]
# capture two digit households

# %%
# Replace NaN with False so missing values are not treated as valid two-digit households
two_digit_house = contracts['household_size'].str.match(r'^\d{1,2}$').astype('boolean').fillna(False)

#extract two digit households
contracts.loc[two_digit_house, 'actual_household_size'] = contracts.loc[two_digit_house, 'household_size'].astype('Int64')

# %%
contracts['actual_household_size'].unique()
# Out:
# <IntegerArray>
# [<NA>, 4, 3, 6, 1, 7, 8, 5, 2, 9, 13, 10, 14, 11, 12, 20, 0, 25, 15, 16, 17,
#  19]
# Length: 22, dtype: Int64

# %%
"""create a boolean filter to separate names from phone numbers """
# filters actual household sizes from mixed datatypes that contains names and contacts
mask_household_size = contracts['household_size'].str.match(r'^\d{1,2}$').astype('bool').fillna(False)
# filter  rows that are not actual household sizes (names + contacts)
mask_phone_name = ~mask_household_size

# %%
# extract phone numbers either in the beginning or end of the string. Also phone number can start with +
contracts.loc[mask_phone_name, 'phone_number'] = (contracts.loc[mask_phone_name, 'household_size'].str.extract(r'(\+?[\d]{9,15})')[0]  
)
# clean up phone numbers by removing special characters and spaces
contracts['phone_number'] = contracts['phone_number'].str.replace(r'[\+\-\(\)\s]', '', regex=True)

# %%
contracts['phone_number'].unique()
# Out:
# array([nan, '256776921622', '256751507695', ..., '256764718509',
#        '256705097664', '256760335303'], dtype=object)

# %%
# extract names
contracts.loc[mask_phone_name, 'name'] = contracts.loc[mask_phone_name, 'household_size'].str.replace(r'(\+?256[\d\-]{6,12}|\d{9,15})', '', regex=True).str.strip()

# %%
#standarize names
contracts['name'] = contracts['name'].str.title()
contracts['name'].unique()
# Out:
# array([nan, 'Erias Matovu', ',  Isubbi Samson', ..., 'Nigesa Marry',
#        'Nabbanja Annet', 'Mukasa  Bonifasi Abubaker'], dtype=object)

# %% [markdown]
# Cannot standardize phone numbers to add country codes because its unclear whether all the contacts are from Ugandan nationals

# %%
# Check updates values
contracts[['actual_household_size', 'phone_number', 'name']].notna().sum()
# Out:
# actual_household_size    8308
# phone_number             1968
# name                     2056
# dtype: int64

# %%
# Take a closer look at the null values
contracts.isna().sum()
# Out:
# contractid                    0
# sales_month                   0
# region                        0
# product                    2166
# sales_person_id            9720
# contract_type                 0
# price_usd                  4561
# payment_frequency         25341
# perc_deposit              25352
# tenor_length              25341
# daily_amount_usd          29080
# customer_gender               0
# household_size           476259
# occupation                59683
# actual_household_size    478315
# phone_number             484655
# name                     484567
# dtype: int64

# %%
#convert contracts to sql
contracts.to_sql('contracts', conn, index=False, if_exists='replace')
# Out:
# 486623

# %%
# test connection
test = """SELECT * FROM contracts

            WHERE phone_number IS NOT NULL
            AND name IS NOT NULL"""
pd.read_sql(test, conn)
# Out:
#       contractid sales_month    region                     product  \
# 0        3579445  2025-05-31  Southern                 Small Solar
# 1        3156433  2024-11-30  Southern                 Small Solar
# 2        3103570  2024-10-31  Southern  Large Solar - Generation 1
# 3        3813825  2025-09-30  Southern                 Small Solar
# 4        3211103  2024-12-31  Southern                 Small Solar
# ...          ...         ...       ...                         ...
# 1963     3754782  2025-08-31  Southern  Large Solar - Generation 2
# 1964     3766446  2025-08-31  Southern                 Small Solar
# 1965     3789151  2025-09-30  Southern                 Small Solar
# 1966     3790585  2025-09-30  Southern                 Small Solar
# 1967     3792662  2025-09-30  Southern                 Small Solar
#
#       sales_person_id contract_type  price_usd payment_frequency  \
# 0            207965.0      FINANCED      150.0             DAILY
# 1            693867.0      FINANCED      150.0             DAILY
# 2            652804.0      FINANCED      300.0             DAILY
# 3            506788.0      FINANCED      150.0             DAILY
# 4            708525.0      FINANCED      150.0             DAILY
# ...               ...           ...        ...               ...
# 1963         927588.0      FINANCED      280.0             DAILY
# 1964         809876.0      FINANCED      150.0             DAILY
# 1965         472915.0      FINANCED      150.0             DAILY
# 1966         272008.0          CASH      150.0              None
# 1967         344790.0      FINANCED      150.0             DAILY
#
#       perc_deposit  tenor_length  daily_amount_usd customer_gender  \
# 0           0.0426         450.0             0.319            Male
# 1           0.0371         450.0             0.321          Female
# 2           0.0569         540.0             0.524          Female
# 3           0.0495         480.0             0.297          Female
# 4           0.0371         450.0             0.321            Male
# ...            ...           ...               ...             ...
# 1963        0.0495         480.0             0.554            Male
# 1964        0.0495         480.0             0.297            Male
# 1965        0.0495         480.0             0.297          Female
# 1966           NaN           NaN               NaN            Male
# 1967        0.0495         480.0             0.297            Male
#
#                                   household_size occupation  \
# 0                     256776921622  Erias Matovu   Business
# 1                   256751507695,  Isubbi Samson   Business
# 2                 256745672789 UPAKRWOTH  DANIEL     Farmer
# 3                    256706348163  wanade Qassim    Teacher
# 4          256745565318     Opiyo Geoffrey James   Business
# ...                                          ...        ...
# 1963  256781860689   Nzyabake Venelanda Rubasaka   Business
# 1964              256746372749 timwesige Jackson     Farmer
# 1965                   256764718509 Nigesa marry     Farmer
# 1966                 256705097664 Nabbanja Annet   Business
# 1967     256760335303  Mukasa  Bonifasi Abubaker   Business
#
#      actual_household_size  phone_number                         name
# 0                     None  256776921622                 Erias Matovu
# 1                     None  256751507695             ,  Isubbi Samson
# 2                     None  256745672789            Upakrwoth  Daniel
# 3                     None  256706348163                Wanade Qassim
# 4                     None  256745565318         Opiyo Geoffrey James
# ...                    ...           ...                          ...
# 1963                  None  256781860689  Nzyabake Venelanda Rubasaka
# 1964                  None  256746372749            Timwesige Jackson
# 1965                  None  256764718509                 Nigesa Marry
# 1966                  None  256705097664               Nabbanja Annet
# 1967                  None  256760335303    Mukasa  Bonifasi Abubaker
#
# [1968 rows x 17 columns]

# %% [markdown]
# ## Clean Null Values

# %%
q1 = """SELECT contract_type, price_usd,perc_deposit, tenor_length, daily_amount_usd
        FROM contracts
        WHERE contract_type = 'FINANCED'
        LIMIT 5 """
pd.read_sql(q1,conn)
# Out:
#   contract_type  price_usd  perc_deposit  tenor_length  daily_amount_usd
# 0      FINANCED      150.0        0.0510         434.0             0.328
# 1      FINANCED      150.0        0.0313         434.0             0.335
# 2      FINANCED      150.0        0.0554         434.0             0.326
# 3      FINANCED      200.0        0.1827         189.0             0.865
# 4      FINANCED        NaN        0.0296         364.0               NaN

# %% [markdown]
# Contracts classified as CASH (one-time payment) do not have financing terms

# %%
q2 = """SELECT contract_type, payment_frequency, price_usd,perc_deposit, tenor_length, daily_amount_usd
        FROM contracts
        WHERE contract_type = 'CASH'
        LIMIT 5 """
pd.read_sql(q2,conn)
# Out:
#   contract_type payment_frequency  price_usd perc_deposit tenor_length  \
# 0          CASH              None      150.0         None         None
# 1          CASH              None      150.0         None         None
# 2          CASH              None      300.0         None         None
# 3          CASH              None      150.0         None         None
# 4          CASH              None      150.0         None         None
#
#   daily_amount_usd
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None

# %%
"""We have 11 instances where tenor_length is not null"""

q4 = """SELECT contract_type,
       SUM(CASE WHEN payment_frequency IS NULL THEN 1 ELSE 0 END) AS pf_nulls,
       SUM(CASE WHEN perc_deposit IS NULL THEN 1 ELSE 0 END) AS deposit_nulls,
       SUM(CASE WHEN tenor_length IS NULL THEN 1 ELSE 0 END) AS tenor_nulls,
       SUM(CASE WHEN daily_amount_usd IS NULL THEN 1 ELSE 0 END) AS daily_nulls,
       COUNT(*) AS total_contracts
FROM contracts
GROUP BY contract_type"""

q4=pd.read_sql(q4,conn)
q4.head()
# Out:
#   contract_type  pf_nulls  deposit_nulls  tenor_nulls  daily_nulls  \
# 0          CASH     25341          25352        25341        25352
# 1      FINANCED         0              0            0         3728
#
#    total_contracts
# 0            25352
# 1           461271

# %%
q5 = """SELECT COUNT(*) AS invalid_cash_contracts
        FROM contracts
        WHERE contract_type = 'CASH'
        AND(
        payment_frequency IS NOT NULL
        OR perc_deposit IS NOT NULL
        OR daily_amount_usd IS NOT NULL
        OR tenor_length IS NOT NULL)
        """
pd.read_sql(q5 , conn)
# Out:
#    invalid_cash_contracts
# 0                      11

# %%
# In these 11 cash contracts, payment_frequency is written as "daily" and tenor_length is 0
q6 = """SELECT * FROM contracts
        WHERE contract_type = 'CASH'
        AND(
        payment_frequency IS NOT NULL
        OR tenor_length IS NOT NULL)"""

pd.read_sql(q6, conn)
# Out:
#     contractid sales_month    region      product sales_person_id  \
# 0      2708359  2024-01-31  Northern  PAYGO_PHONE            None
# 1      2686003  2024-01-31  Northern  PAYGO_PHONE            None
# 2      2704071  2024-01-31  Northern  PAYGO_PHONE            None
# 3      2709900  2024-01-31  Northern  PAYGO_PHONE            None
# 4      2686001  2024-01-31  Northern  PAYGO_PHONE            None
# 5      2929007  2024-06-30  Northern  PAYGO_PHONE            None
# 6      2908726  2024-06-30  Northern  PAYGO_PHONE            None
# 7      3453167  2025-03-31  Northern  PAYGO_PHONE            None
# 8      2761329  2024-02-29  Northern  PAYGO_PHONE            None
# 9      2905940  2024-06-30  Northern  PAYGO_PHONE            None
# 10     2908916  2024-06-30  Northern         None            None
#
#    contract_type  price_usd payment_frequency perc_deposit  tenor_length  \
# 0           CASH      200.0             DAILY         None           0.0
# 1           CASH      200.0             DAILY         None           0.0
# 2           CASH      200.0             DAILY         None           0.0
# 3           CASH      200.0             DAILY         None           0.0
# 4           CASH      200.0             DAILY         None           0.0
# 5           CASH      200.0             DAILY         None           0.0
# 6           CASH      200.0             DAILY         None           0.0
# 7           CASH      200.0             DAILY         None           0.0
# 8           CASH      200.0             DAILY         None           0.0
# 9           CASH      200.0             DAILY         None           0.0
# 10          CASH        NaN             DAILY         None           0.0
#
#    daily_amount_usd customer_gender household_size occupation  \
# 0              None            Male           None   Business
# 1              None          Female           None       None
# 2              None          Female           None   Business
# 3              None            Male           None      Other
# 4              None            Male           None      Other
# 5              None            Male           None   Business
# 6              None            Male              4   Labourer
# 7              None            Male           None       None
# 8              None          Female           None       None
# 9              None          Female              3   Business
# 10             None            Male           None   Business
#
#     actual_household_size phone_number  name
# 0                     NaN         None  None
# 1                     NaN         None  None
# 2                     NaN         None  None
# 3                     NaN         None  None
# 4                     NaN         None  None
# 5                     NaN         None  None
# 6                     4.0         None  None
# 7                     NaN         None  None
# 8                     NaN         None  None
# 9                     3.0         None  None
# 10                    NaN         None  None

# %% [markdown]
# In the documentation,
# - perc_deposit for CASH contracts is 1 and for FINANCED contracts is the deposit required (in USD) as percentage of total value.
#
# - tenor_length is number of days (even if they are not required to pay daily this value is in DAYS) customer must pay to fully pay off the contract
#
# ***Therefore, ill fill the null tenor length values with 0 to represent 0 days as cash contracts do not have tenor length and fill null perc deposit with 1. Ill replace the 'Daily' payment frequency with NULL as Cash payments are a one-time payment***

# %%
update_contracts = """
UPDATE contracts
SET 
    perc_deposit = 1,               -- full payment upfront
    tenor_length = 0,
    payment_frequency = NULL

WHERE contract_type = 'CASH'
"""
# execute the update
cursor.execute(update_contracts)

# commit the changes
conn.commit()

# %%
# inspect 
nulls = """SELECT * FROM contracts
        WHERE contract_type = 'CASH'
        AND(
        payment_frequency IS NOT NULL
        OR tenor_length IS NOT NULL)"""

       
pd.read_sql(nulls , conn)
# Out:
#        contractid sales_month    region                     product  \
# 0         3591244  2025-05-31  Southern                 Small Solar
# 1         2833147  2024-04-30  Southern                 Small Solar
# 2         3321226  2025-01-31  Southern  Large Solar - Generation 1
# 3         2849697  2024-04-30   Western                 Small Solar
# 4         2803810  2024-03-31   Western                 Small Solar
# ...           ...         ...       ...                         ...
# 25347     3815513  2025-09-30   Western                 Small Solar
# 25348     3815643  2025-09-30   Western  Large Solar - Generation 2
# 25349     3815672  2025-09-30   Western  Large Solar - Generation 2
# 25350     3818975  2025-09-30   Western                 Small Solar
# 25351     3818228  2025-09-30   Western                 Small Solar
#
#        sales_person_id contract_type  price_usd payment_frequency  \
# 0             418845.0          CASH      150.0              None
# 1             577862.0          CASH      150.0              None
# 2             534838.0          CASH      300.0              None
# 3             226990.0          CASH      150.0              None
# 4             353729.0          CASH      150.0              None
# ...                ...           ...        ...               ...
# 25347         961082.0          CASH      150.0              None
# 25348         978783.0          CASH      280.0              None
# 25349         291803.0          CASH      280.0              None
# 25350         148824.0          CASH      150.0              None
# 25351         342536.0          CASH      150.0              None
#
#        perc_deposit  tenor_length daily_amount_usd customer_gender  \
# 0               1.0           0.0             None          Female
# 1               1.0           0.0             None          Female
# 2               1.0           0.0             None          Female
# 3               1.0           0.0             None            Male
# 4               1.0           0.0             None            Male
# ...             ...           ...              ...             ...
# 25347           1.0           0.0             None            Male
# 25348           1.0           0.0             None          Female
# 25349           1.0           0.0             None          Female
# 25350           1.0           0.0             None          Female
# 25351           1.0           0.0             None          Female
#
#       household_size           occupation  actual_household_size phone_number  \
# 0                  6             Labourer                    6.0         None
# 1               None             Business                    NaN         None
# 2                  3                Other                    3.0         None
# 3               None             Business                    NaN         None
# 4                  5  Government Employee                    5.0         None
# ...              ...                  ...                    ...          ...
# 25347           None             Business                    NaN         None
# 25348           None                 None                    NaN         None
# 25349           None                 None                    NaN         None
# 25350           None             Business                    NaN         None
# 25351           None             Business                    NaN         None
#
#        name
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 25347  None
# 25348  None
# 25349  None
# 25350  None
# 25351  None
#
# [25352 rows x 17 columns]

# %% [markdown]
# Take a closer look at financed columns

# %%
financed_nulls = """SELECT
    SUM(CASE WHEN payment_frequency IS NULL THEN 1 ELSE 0 END) AS pf_nulls,
    SUM(CASE WHEN perc_deposit IS NULL THEN 1 ELSE 0 END) AS deposit_nulls,
    SUM(CASE WHEN tenor_length IS NULL THEN 1 ELSE 0 END) AS tenor_nulls,
    SUM(CASE WHEN daily_amount_usd IS NULL THEN 1 ELSE 0 END) AS daily_nulls
FROM contracts
WHERE contract_type = 'FINANCED'
"""
pd.read_sql(financed_nulls,conn)
# Out:
#    pf_nulls  deposit_nulls  tenor_nulls  daily_nulls
# 0         0              0            0         3728

# %%
f_nulls = """ SELECT * FROM contracts
              WHERE daily_amount_usd IS NULL
              AND contract_type = 'FINANCED' """

pd.read_sql(f_nulls, conn)
# Out:
#       contractid sales_month    region                     product  \
# 0        3674681  2025-06-30   Western                 Small Solar
# 1        3443355  2025-03-31  Southern  Large Solar - Generation 2
# 2        3108860  2024-10-31   Western                        None
# 3        2888739  2024-05-31  Northern                        None
# 4        3039294  2024-08-31  Northern                        None
# ...          ...         ...       ...                         ...
# 3723     3814403  2025-09-30  Northern                        None
# 3724     3756025  2025-08-31  Southern  Large Solar - Generation 2
# 3725     3761205  2025-08-31   Western                 Small Solar
# 3726     3800719  2025-09-30   Western                 Small Solar
# 3727     3814022  2025-09-30  Southern  Large Solar - Generation 2
#
#       sales_person_id contract_type price_usd payment_frequency  perc_deposit  \
# 0            813534.0      FINANCED      None            WEEKLY        0.0296
# 1            413796.0      FINANCED      None             DAILY        0.0442
# 2            782850.0      FINANCED      None            WEEKLY        0.0374
# 3            242074.0      FINANCED      None             DAILY        0.0576
# 4            307572.0      FINANCED      None             DAILY        0.0576
# ...               ...           ...       ...               ...           ...
# 3723         947527.0      FINANCED      None             DAILY        0.0560
# 3724         958705.0      FINANCED      None             DAILY        0.0495
# 3725         125352.0      FINANCED      None            WEEKLY        0.0253
# 3726         208812.0      FINANCED      None            WEEKLY        0.0313
# 3727         698255.0      FINANCED      None             DAILY        0.0495
#
#       tenor_length daily_amount_usd customer_gender household_size occupation  \
# 0            364.0             None            Male           None   Business
# 1            540.0             None            Male           None   Business
# 2            665.0             None            Male           None     Farmer
# 3            640.0             None            Male           None   Business
# 4            640.0             None            Male           None   Business
# ...            ...              ...             ...            ...        ...
# 3723         640.0             None          Female           None       None
# 3724         480.0             None            Male           None     Farmer
# 3725         434.0             None          Female           None      Other
# 3726         434.0             None          Female           None     Farmer
# 3727         480.0             None          Female           None   Business
#
#       actual_household_size phone_number  name
# 0                       NaN         None  None
# 1                       NaN         None  None
# 2                       NaN         None  None
# 3                       NaN         None  None
# 4                       NaN         None  None
# ...                     ...          ...   ...
# 3723                    NaN         None  None
# 3724                    NaN         None  None
# 3725                    NaN         None  None
# 3726                    NaN         None  None
# 3727                    NaN         None  None
#
# [3728 rows x 17 columns]

# %% [markdown]
# Assumption for filling missing daily_amount_usd in FINANCED contracts:
# - Using the available fields: payment_frequency, perc_deposit, and tenor_length, we can make an assumption to estimate price and daily payment.
# - Estimate method (assumption):
#     1. Estimate price_usd using the average price of the same product where price_usd is missing.
#     2. Compute financed amount = price_usd * (1 - perc_deposit)
#     3. Compute daily_amount_usd = financed_amount / tenor_length
# - This is purely an assumption for data completeness and may not reflect the actual contract value.

# %%
# Add a flag column to this track assumptions
assumptions_flag = """
ALTER TABLE contracts 
ADD COLUMN assumption_flag VARCHAR(20)"""

cursor.execute(assumptions_flag)
conn.commit()

# %%
"""create an assumption flag to show all the values that have been imputed"""

assumptions = """UPDATE contracts
                SET assumption_flag = CASE
                      WHEN price_usd IS NULL OR daily_amount_usd IS NULL 
                      THEN 'ASSUMPTION'
                      ELSE 'ORIGINAL'
                      END """
# execute the update
cursor.execute(assumptions)

# commit the changes
conn.commit()

# %%
updates_nulls_prices = """ 
UPDATE CONTRACTS
SET price_usd = CASE
                    WHEN product = 'Small Solar' THEN 150
                    WHEN product = 'PAYGO_PHONE' THEN 200
                    WHEN product = 'Large Solar - Generation 1' THEN 300
                    WHEN product = 'Large Solar - Generation 2' THEN 280
                    WHEN product = 'PAYGO_PORTABLE' THEN 100
                    END
WHERE contract_type = 'FINANCED'
AND price_usd IS NULL """

# execute the update
cursor.execute(updates_nulls_prices)

# commit the changes
conn.commit()

# %%
# Compute missing daily_amount_usd based on price, perc_deposit, and tenor_length

update_daily_amt = """
UPDATE contracts
SET daily_amount_usd = (price_usd * (1 - perc_deposit)) / tenor_length
WHERE contract_type = 'FINANCED'
  AND daily_amount_usd IS NULL
  AND price_usd IS NOT NULL
  AND perc_deposit IS NOT NULL
  AND tenor_length IS NOT NULL"""
cursor.execute(update_daily_amt)
conn.commit()

# %%
"""check number of null values left"""
nulls = """SELECT * 
FROM contracts
WHERE contract_type = 'FINANCED'
AND daily_amount_usd IS NULL """

pd.read_sql(nulls, conn)
# Out:
#       contractid sales_month    region product  sales_person_id contract_type  \
# 0        3108860  2024-10-31   Western    None         782850.0      FINANCED
# 1        2888739  2024-05-31  Northern    None         242074.0      FINANCED
# 2        3039294  2024-08-31  Northern    None         307572.0      FINANCED
# 3        3622217  2025-05-31  Northern    None         844770.0      FINANCED
# 4        2852364  2024-04-30  Northern    None         277342.0      FINANCED
# ...          ...         ...       ...     ...              ...           ...
# 1451     3756624  2025-08-31   Western    None         979914.0      FINANCED
# 1452     3654080  2025-06-30  Northern    None         874439.0      FINANCED
# 1453     3674495  2025-06-30   Western    None         917325.0      FINANCED
# 1454     3687403  2025-07-31  Northern    None         366638.0      FINANCED
# 1455     3814403  2025-09-30  Northern    None         947527.0      FINANCED
#
#      price_usd payment_frequency  perc_deposit  tenor_length daily_amount_usd  \
# 0         None            WEEKLY        0.0374         665.0             None
# 1         None             DAILY        0.0576         640.0             None
# 2         None             DAILY        0.0576         640.0             None
# 3         None             DAILY        0.0560         640.0             None
# 4         None             DAILY        0.0442         540.0             None
# ...        ...               ...           ...           ...              ...
# 1451      None            WEEKLY        0.0324         504.0             None
# 1452      None             DAILY        0.0560         640.0             None
# 1453      None            WEEKLY        0.0328         371.0             None
# 1454      None             DAILY        0.0560         640.0             None
# 1455      None             DAILY        0.0560         640.0             None
#
#      customer_gender household_size occupation  actual_household_size  \
# 0               Male           None     Farmer                    NaN
# 1               Male           None   Business                    NaN
# 2               Male           None   Business                    NaN
# 3               Male           None    Teacher                    NaN
# 4             Female           None     Farmer                    NaN
# ...              ...            ...        ...                    ...
# 1451            Male           None   Business                    NaN
# 1452            Male           None     Farmer                    NaN
# 1453            Male           None   Business                    NaN
# 1454          Female           None     Farmer                    NaN
# 1455          Female           None       None                    NaN
#
#      phone_number  name assumption_flag
# 0            None  None      ASSUMPTION
# 1            None  None      ASSUMPTION
# 2            None  None      ASSUMPTION
# 3            None  None      ASSUMPTION
# 4            None  None      ASSUMPTION
# ...           ...   ...             ...
# 1451         None  None      ASSUMPTION
# 1452         None  None      ASSUMPTION
# 1453         None  None      ASSUMPTION
# 1454         None  None      ASSUMPTION
# 1455         None  None      ASSUMPTION
#
# [1456 rows x 18 columns]

# %% [markdown]
# There are 1456 null values left. Some price null values also have product field as null. Without product type we cannot assign a price using assumptions.

# %%
null_products = """
SELECT *
FROM contracts
WHERE contract_type = 'FINANCED'
AND product IS NULL """

pd.read_sql(null_products, conn)
# Out:
#       contractid sales_month    region product  sales_person_id contract_type  \
# 0        3108860  2024-10-31   Western    None         782850.0      FINANCED
# 1        2888739  2024-05-31  Northern    None         242074.0      FINANCED
# 2        3039294  2024-08-31  Northern    None         307572.0      FINANCED
# 3        3622217  2025-05-31  Northern    None         844770.0      FINANCED
# 4        2852364  2024-04-30  Northern    None         277342.0      FINANCED
# ...          ...         ...       ...     ...              ...           ...
# 1451     3756624  2025-08-31   Western    None         979914.0      FINANCED
# 1452     3654080  2025-06-30  Northern    None         874439.0      FINANCED
# 1453     3674495  2025-06-30   Western    None         917325.0      FINANCED
# 1454     3687403  2025-07-31  Northern    None         366638.0      FINANCED
# 1455     3814403  2025-09-30  Northern    None         947527.0      FINANCED
#
#      price_usd payment_frequency  perc_deposit  tenor_length daily_amount_usd  \
# 0         None            WEEKLY        0.0374         665.0             None
# 1         None             DAILY        0.0576         640.0             None
# 2         None             DAILY        0.0576         640.0             None
# 3         None             DAILY        0.0560         640.0             None
# 4         None             DAILY        0.0442         540.0             None
# ...        ...               ...           ...           ...              ...
# 1451      None            WEEKLY        0.0324         504.0             None
# 1452      None             DAILY        0.0560         640.0             None
# 1453      None            WEEKLY        0.0328         371.0             None
# 1454      None             DAILY        0.0560         640.0             None
# 1455      None             DAILY        0.0560         640.0             None
#
#      customer_gender household_size occupation  actual_household_size  \
# 0               Male           None     Farmer                    NaN
# 1               Male           None   Business                    NaN
# 2               Male           None   Business                    NaN
# 3               Male           None    Teacher                    NaN
# 4             Female           None     Farmer                    NaN
# ...              ...            ...        ...                    ...
# 1451            Male           None   Business                    NaN
# 1452            Male           None     Farmer                    NaN
# 1453            Male           None   Business                    NaN
# 1454          Female           None     Farmer                    NaN
# 1455          Female           None       None                    NaN
#
#      phone_number  name assumption_flag
# 0            None  None      ASSUMPTION
# 1            None  None      ASSUMPTION
# 2            None  None      ASSUMPTION
# 3            None  None      ASSUMPTION
# 4            None  None      ASSUMPTION
# ...           ...   ...             ...
# 1451         None  None      ASSUMPTION
# 1452         None  None      ASSUMPTION
# 1453         None  None      ASSUMPTION
# 1454         None  None      ASSUMPTION
# 1455         None  None      ASSUMPTION
#
# [1456 rows x 18 columns]

# %% [markdown]
# The 1456 null values also coincide with number of rows will no product info.
#
# - Flag all records without products by creating a new table and copy incomplete rows into it

# %%
#create table to move all records with null product values for further analysis
table_creation= """CREATE TABLE null_financed_products AS
SELECT *
FROM contracts
WHERE contract_type = 'FINANCED'
AND product IS NULL"""

cursor.execute(table_creation)
conn.commit
# Out:
# <function Connection.commit()>

# %%
# create an incomplete flag column that flags all columns with null product values
flag_complete = """ALTER TABLE contracts
                    ADD incomplete_flag VARCHAR(20)"""
cursor.execute(flag_complete)
conn.commit
# Out:
# <function Connection.commit()>

# %%
#set default
update = """UPDATE contracts
                    SET incomplete_flag = 'COMPLETE'
                    WHERE incomplete_flag IS NULL"""
cursor.execute(update)
conn.commit()

# %%
q7 = """SELECT * FROM contracts"""
pd.read_sql(q7 , conn)
# Out:
#         contractid sales_month    region                     product  \
# 0          3098268  2024-10-31   Western                 Small Solar
# 1          3554125  2025-04-30   Western                 Small Solar
# 2          2792627  2024-03-31   Western                 Small Solar
# 3          2869807  2024-05-31   Western                 PAYGO_PHONE
# 4          3674681  2025-06-30   Western                 Small Solar
# ...            ...         ...       ...                         ...
# 486618     3817296  2025-09-30  Southern                 Small Solar
# 486619     3817534  2025-09-30  Southern                 Small Solar
# 486620     3817434  2025-09-30  Northern              PAYGO_PORTABLE
# 486621     3817380  2025-09-30  Northern  Large Solar - Generation 2
# 486622     3820831  2025-09-30   Western                 Small Solar
#
#         sales_person_id contract_type  price_usd payment_frequency  \
# 0              154077.0      FINANCED      150.0            WEEKLY
# 1              878345.0      FINANCED      150.0            WEEKLY
# 2              648775.0      FINANCED      150.0            WEEKLY
# 3              328066.0      FINANCED      200.0            WEEKLY
# 4              813534.0      FINANCED      150.0            WEEKLY
# ...                 ...           ...        ...               ...
# 486618         670507.0      FINANCED      150.0             DAILY
# 486619         884340.0      FINANCED      150.0             DAILY
# 486620         246897.0      FINANCED      100.0          TRIDAILY
# 486621         500619.0      FINANCED      280.0             DAILY
# 486622         153455.0      FINANCED      150.0            WEEKLY
#
#         perc_deposit  tenor_length  daily_amount_usd customer_gender  \
# 0             0.0510         434.0           0.32800            Male
# 1             0.0313         434.0           0.33500            Male
# 2             0.0554         434.0           0.32600            Male
# 3             0.1827         189.0           0.86500            Male
# 4             0.0296         364.0           0.39989            Male
# ...              ...           ...               ...             ...
# 486618        0.0495         480.0           0.29700            Male
# 486619        0.0495         480.0           0.29700          Female
# 486620        0.0401         399.0           0.24100            Male
# 486621        0.0565         640.0           0.41300          Female
# 486622        0.0268         406.0           0.36000            Male
#
#        household_size           occupation  actual_household_size  \
# 0                None              Teacher                    NaN
# 1                None              Teacher                    NaN
# 2                   4  Government Employee                    4.0
# 3                None             Business                    NaN
# 4                None             Business                    NaN
# ...               ...                  ...                    ...
# 486618           None             Labourer                    NaN
# 486619           None             Business                    NaN
# 486620           None               Farmer                    NaN
# 486621           None             Business                    NaN
# 486622           None             Business                    NaN
#
#        phone_number  name assumption_flag incomplete_flag
# 0              None  None        ORIGINAL        COMPLETE
# 1              None  None        ORIGINAL        COMPLETE
# 2              None  None        ORIGINAL        COMPLETE
# 3              None  None        ORIGINAL        COMPLETE
# 4              None  None      ASSUMPTION        COMPLETE
# ...             ...   ...             ...             ...
# 486618         None  None        ORIGINAL        COMPLETE
# 486619         None  None        ORIGINAL        COMPLETE
# 486620         None  None        ORIGINAL        COMPLETE
# 486621         None  None        ORIGINAL        COMPLETE
# 486622         None  None        ORIGINAL        COMPLETE
#
# [486623 rows x 19 columns]

# %% [markdown]
# check for more null values

# %%
q8 = """select * from contracts
        WHERE contract_type = 'CASH'
        AND product IS NULL
"""
pd.read_sql(q8 , conn)
# Out:
#      contractid sales_month    region product  sales_person_id contract_type  \
# 0       2711666  2024-01-31  Northern    None         509405.0          CASH
# 1       2702597  2024-01-31  Northern    None         369385.0          CASH
# 2       2697995  2024-01-31  Northern    None         442594.0          CASH
# 3       2714710  2024-01-31  Northern    None         393223.0          CASH
# 4       3093451  2024-09-30   Western    None         182684.0          CASH
# ..          ...         ...       ...     ...              ...           ...
# 705     3165594  2024-11-30  Southern    None         839926.0          CASH
# 706     3788006  2025-09-30  Southern    None         309405.0          CASH
# 707     3694870  2025-07-31  Southern    None              NaN          CASH
# 708     3711431  2025-07-31   Eastern    None         120402.0          CASH
# 709     3787510  2025-09-30   Western    None         675932.0          CASH
#
#     price_usd payment_frequency  perc_deposit  tenor_length daily_amount_usd  \
# 0        None              None           1.0           0.0             None
# 1        None              None           1.0           0.0             None
# 2        None              None           1.0           0.0             None
# 3        None              None           1.0           0.0             None
# 4        None              None           1.0           0.0             None
# ..        ...               ...           ...           ...              ...
# 705      None              None           1.0           0.0             None
# 706      None              None           1.0           0.0             None
# 707      None              None           1.0           0.0             None
# 708      None              None           1.0           0.0             None
# 709      None              None           1.0           0.0             None
#
#     customer_gender household_size occupation  actual_household_size  \
# 0            Female              2   Business                    2.0
# 1              Male              3     Farmer                    3.0
# 2            Female              8   Business                    8.0
# 3              Male              2   Business                    2.0
# 4              Male           None   Business                    NaN
# ..              ...            ...        ...                    ...
# 705          Female           None     Farmer                    NaN
# 706          Female              5   Business                    5.0
# 707            Male              5     Farmer                    5.0
# 708            Male           None       None                    NaN
# 709            Male           None   Business                    NaN
#
#     phone_number  name assumption_flag incomplete_flag
# 0           None  None      ASSUMPTION        COMPLETE
# 1           None  None      ASSUMPTION        COMPLETE
# 2           None  None      ASSUMPTION        COMPLETE
# 3           None  None      ASSUMPTION        COMPLETE
# 4           None  None      ASSUMPTION        COMPLETE
# ..           ...   ...             ...             ...
# 705         None  None      ASSUMPTION        COMPLETE
# 706         None  None      ASSUMPTION        COMPLETE
# 707         None  None      ASSUMPTION        COMPLETE
# 708         None  None      ASSUMPTION        COMPLETE
# 709         None  None      ASSUMPTION        COMPLETE
#
# [710 rows x 19 columns]

# %%
"""Some cash contracts have the product type but dont have the product price (price_usd). check for instances with
product but no price_usd """

price_null = """SELECT * FROM contracts WHERE product IS NOT NULL AND price_usd IS NULL;
"""
pd.read_sql(price_null , conn)
# Out:
#      contractid sales_month    region                     product  \
# 0       3517826  2025-04-30  Southern                 Small Solar
# 1       3516113  2025-04-30   Western  Large Solar - Generation 1
# 2       2681810  2024-01-31  Northern  Large Solar - Generation 1
# 3       2850545  2024-04-30  Northern              PAYGO_PORTABLE
# 4       3776342  2025-08-31   Western                 Small Solar
# ..          ...         ...       ...                         ...
# 118     2937716  2024-06-30  Northern              PAYGO_PORTABLE
# 119     3618473  2025-05-31  Southern  Large Solar - Generation 2
# 120     3456969  2025-03-31  Northern                 Small Solar
# 121     3511106  2025-04-30   Western                 Small Solar
# 122     3788903  2025-09-30  Northern                 Small Solar
#
#      sales_person_id contract_type price_usd payment_frequency  perc_deposit  \
# 0           299803.0          CASH      None              None           1.0
# 1           899264.0          CASH      None              None           1.0
# 2                NaN          CASH      None              None           1.0
# 3           906267.0          CASH      None              None           1.0
# 4           567163.0          CASH      None              None           1.0
# ..               ...           ...       ...               ...           ...
# 118         365572.0          CASH      None              None           1.0
# 119         475515.0          CASH      None              None           1.0
# 120         297565.0          CASH      None              None           1.0
# 121         973414.0          CASH      None              None           1.0
# 122         210926.0          CASH      None              None           1.0
#
#      tenor_length daily_amount_usd customer_gender household_size occupation  \
# 0             0.0             None            Male           None   Business
# 1             0.0             None            Male           None   Business
# 2             0.0             None            Male           None   Business
# 3             0.0             None            Male           None      Other
# 4             0.0             None            Male              4   Business
# ..            ...              ...             ...            ...        ...
# 118           0.0             None            Male           None     Farmer
# 119           0.0             None            Male           None     Farmer
# 120           0.0             None          Female           None       None
# 121           0.0             None            Male           None      Other
# 122           0.0             None            Male           None       None
#
#      actual_household_size phone_number  name assumption_flag incomplete_flag
# 0                      NaN         None  None      ASSUMPTION        COMPLETE
# 1                      NaN         None  None      ASSUMPTION        COMPLETE
# 2                      NaN         None  None      ASSUMPTION        COMPLETE
# 3                      NaN         None  None      ASSUMPTION        COMPLETE
# 4                      4.0         None  None      ASSUMPTION        COMPLETE
# ..                     ...          ...   ...             ...             ...
# 118                    NaN         None  None      ASSUMPTION        COMPLETE
# 119                    NaN         None  None      ASSUMPTION        COMPLETE
# 120                    NaN         None  None      ASSUMPTION        COMPLETE
# 121                    NaN         None  None      ASSUMPTION        COMPLETE
# 122                    NaN         None  None      ASSUMPTION        COMPLETE
#
# [123 rows x 19 columns]

# %%
"""There are 123 cash rows that have product but no product price. Use assumptions to fill them"""
update_price = """
    UPDATE contracts
    SET price_usd = CASE 
                    WHEN product = 'Small Solar' THEN 150
                    WHEN product = 'PAYGO_PHONE' THEN 200
                    WHEN product = 'Large Solar - Generation 1' THEN 300
                    WHEN product = 'Large Solar - Generation 2' THEN 280
                    WHEN product = 'PAYGO_PORTABLE' THEN 100
                    ELSE price_usd  
                END
WHERE contract_type = 'CASH'
  AND price_usd IS NULL;
"""
cursor.execute(update_price)
conn.commit()

# %%
price_null = """SELECT  * FROM contracts WHERE price_usd IS NULL
"""
pd.read_sql(price_null, conn)
# Out:
#       contractid sales_month    region product  sales_person_id contract_type  \
# 0        3108860  2024-10-31   Western    None         782850.0      FINANCED
# 1        2888739  2024-05-31  Northern    None         242074.0      FINANCED
# 2        2711666  2024-01-31  Northern    None         509405.0          CASH
# 3        3039294  2024-08-31  Northern    None         307572.0      FINANCED
# 4        2702597  2024-01-31  Northern    None         369385.0          CASH
# ...          ...         ...       ...     ...              ...           ...
# 2161     3654080  2025-06-30  Northern    None         874439.0      FINANCED
# 2162     3674495  2025-06-30   Western    None         917325.0      FINANCED
# 2163     3787510  2025-09-30   Western    None         675932.0          CASH
# 2164     3687403  2025-07-31  Northern    None         366638.0      FINANCED
# 2165     3814403  2025-09-30  Northern    None         947527.0      FINANCED
#
#      price_usd payment_frequency  perc_deposit  tenor_length daily_amount_usd  \
# 0         None            WEEKLY        0.0374         665.0             None
# 1         None             DAILY        0.0576         640.0             None
# 2         None              None        1.0000           0.0             None
# 3         None             DAILY        0.0576         640.0             None
# 4         None              None        1.0000           0.0             None
# ...        ...               ...           ...           ...              ...
# 2161      None             DAILY        0.0560         640.0             None
# 2162      None            WEEKLY        0.0328         371.0             None
# 2163      None              None        1.0000           0.0             None
# 2164      None             DAILY        0.0560         640.0             None
# 2165      None             DAILY        0.0560         640.0             None
#
#      customer_gender household_size occupation  actual_household_size  \
# 0               Male           None     Farmer                    NaN
# 1               Male           None   Business                    NaN
# 2             Female              2   Business                    2.0
# 3               Male           None   Business                    NaN
# 4               Male              3     Farmer                    3.0
# ...              ...            ...        ...                    ...
# 2161            Male           None     Farmer                    NaN
# 2162            Male           None   Business                    NaN
# 2163            Male           None   Business                    NaN
# 2164          Female           None     Farmer                    NaN
# 2165          Female           None       None                    NaN
#
#      phone_number  name assumption_flag incomplete_flag
# 0            None  None      ASSUMPTION        COMPLETE
# 1            None  None      ASSUMPTION        COMPLETE
# 2            None  None      ASSUMPTION        COMPLETE
# 3            None  None      ASSUMPTION        COMPLETE
# 4            None  None      ASSUMPTION        COMPLETE
# ...           ...   ...             ...             ...
# 2161         None  None      ASSUMPTION        COMPLETE
# 2162         None  None      ASSUMPTION        COMPLETE
# 2163         None  None      ASSUMPTION        COMPLETE
# 2164         None  None      ASSUMPTION        COMPLETE
# 2165         None  None      ASSUMPTION        COMPLETE
#
# [2166 rows x 19 columns]

# %%
product_null = """SELECT * FROM contracts WHERE product IS NULL"""
pd.read_sql(product_null, conn)
# Out:
#       contractid sales_month    region product  sales_person_id contract_type  \
# 0        3108860  2024-10-31   Western    None         782850.0      FINANCED
# 1        2888739  2024-05-31  Northern    None         242074.0      FINANCED
# 2        2711666  2024-01-31  Northern    None         509405.0          CASH
# 3        3039294  2024-08-31  Northern    None         307572.0      FINANCED
# 4        2702597  2024-01-31  Northern    None         369385.0          CASH
# ...          ...         ...       ...     ...              ...           ...
# 2161     3654080  2025-06-30  Northern    None         874439.0      FINANCED
# 2162     3674495  2025-06-30   Western    None         917325.0      FINANCED
# 2163     3787510  2025-09-30   Western    None         675932.0          CASH
# 2164     3687403  2025-07-31  Northern    None         366638.0      FINANCED
# 2165     3814403  2025-09-30  Northern    None         947527.0      FINANCED
#
#      price_usd payment_frequency  perc_deposit  tenor_length daily_amount_usd  \
# 0         None            WEEKLY        0.0374         665.0             None
# 1         None             DAILY        0.0576         640.0             None
# 2         None              None        1.0000           0.0             None
# 3         None             DAILY        0.0576         640.0             None
# 4         None              None        1.0000           0.0             None
# ...        ...               ...           ...           ...              ...
# 2161      None             DAILY        0.0560         640.0             None
# 2162      None            WEEKLY        0.0328         371.0             None
# 2163      None              None        1.0000           0.0             None
# 2164      None             DAILY        0.0560         640.0             None
# 2165      None             DAILY        0.0560         640.0             None
#
#      customer_gender household_size occupation  actual_household_size  \
# 0               Male           None     Farmer                    NaN
# 1               Male           None   Business                    NaN
# 2             Female              2   Business                    2.0
# 3               Male           None   Business                    NaN
# 4               Male              3     Farmer                    3.0
# ...              ...            ...        ...                    ...
# 2161            Male           None     Farmer                    NaN
# 2162            Male           None   Business                    NaN
# 2163            Male           None   Business                    NaN
# 2164          Female           None     Farmer                    NaN
# 2165          Female           None       None                    NaN
#
#      phone_number  name assumption_flag incomplete_flag
# 0            None  None      ASSUMPTION        COMPLETE
# 1            None  None      ASSUMPTION        COMPLETE
# 2            None  None      ASSUMPTION        COMPLETE
# 3            None  None      ASSUMPTION        COMPLETE
# 4            None  None      ASSUMPTION        COMPLETE
# ...           ...   ...             ...             ...
# 2161         None  None      ASSUMPTION        COMPLETE
# 2162         None  None      ASSUMPTION        COMPLETE
# 2163         None  None      ASSUMPTION        COMPLETE
# 2164         None  None      ASSUMPTION        COMPLETE
# 2165         None  None      ASSUMPTION        COMPLETE
#
# [2166 rows x 19 columns]

# %% [markdown]
# There are 2166 fields left. This are fields that dont have any product values hence no procuct price value. I will flag all columns with null values

# %% [markdown]
# The incomplete_flag counts the number of missing important fields
# - Always checks `product` and `price_usd` for all contracts
# - Checks `tenor_length`, `daily_amount_usd`, `perc_deposit` only for FINANCED contracts as this fields are only relevant to this contract type
#
# ***The result is the total number of missing fields relevant to the contract type***

# %%
fill_incomplete_flag = """UPDATE contracts
                        SET incomplete_flag = COALESCE(
                        CAST(
                        (CASE WHEN product IS NULL THEN 1 ELSE 0 END) +
                        (CASE WHEN sales_person_id IS NULL THEN 1 ELSE 0 END)+
                        (CASE WHEN price_usd IS NULL THEN 1 ELSE 0 END) +
                        (CASE WHEN contract_type = 'FINANCED' AND tenor_length IS NULL THEN 1 ELSE 0 END) +
                        (CASE WHEN contract_type = 'FINANCED' AND daily_amount_usd IS NULL THEN 1 ELSE 0 END) +
                        (CASE WHEN contract_type = 'FINANCED' AND perc_deposit IS NULL THEN 1 ELSE 0 END)
                        AS TEXT),
                            '0'
)"""  
cursor.execute(fill_incomplete_flag)
conn.commit()

# %%
q9 = """SELECT * FROM contracts"""
pd.read_sql(q9, conn)
# Out:
#         contractid sales_month    region                     product  \
# 0          3098268  2024-10-31   Western                 Small Solar
# 1          3554125  2025-04-30   Western                 Small Solar
# 2          2792627  2024-03-31   Western                 Small Solar
# 3          2869807  2024-05-31   Western                 PAYGO_PHONE
# 4          3674681  2025-06-30   Western                 Small Solar
# ...            ...         ...       ...                         ...
# 486618     3817296  2025-09-30  Southern                 Small Solar
# 486619     3817534  2025-09-30  Southern                 Small Solar
# 486620     3817434  2025-09-30  Northern              PAYGO_PORTABLE
# 486621     3817380  2025-09-30  Northern  Large Solar - Generation 2
# 486622     3820831  2025-09-30   Western                 Small Solar
#
#         sales_person_id contract_type  price_usd payment_frequency  \
# 0              154077.0      FINANCED      150.0            WEEKLY
# 1              878345.0      FINANCED      150.0            WEEKLY
# 2              648775.0      FINANCED      150.0            WEEKLY
# 3              328066.0      FINANCED      200.0            WEEKLY
# 4              813534.0      FINANCED      150.0            WEEKLY
# ...                 ...           ...        ...               ...
# 486618         670507.0      FINANCED      150.0             DAILY
# 486619         884340.0      FINANCED      150.0             DAILY
# 486620         246897.0      FINANCED      100.0          TRIDAILY
# 486621         500619.0      FINANCED      280.0             DAILY
# 486622         153455.0      FINANCED      150.0            WEEKLY
#
#         perc_deposit  tenor_length  daily_amount_usd customer_gender  \
# 0             0.0510         434.0           0.32800            Male
# 1             0.0313         434.0           0.33500            Male
# 2             0.0554         434.0           0.32600            Male
# 3             0.1827         189.0           0.86500            Male
# 4             0.0296         364.0           0.39989            Male
# ...              ...           ...               ...             ...
# 486618        0.0495         480.0           0.29700            Male
# 486619        0.0495         480.0           0.29700          Female
# 486620        0.0401         399.0           0.24100            Male
# 486621        0.0565         640.0           0.41300          Female
# 486622        0.0268         406.0           0.36000            Male
#
#        household_size           occupation  actual_household_size  \
# 0                None              Teacher                    NaN
# 1                None              Teacher                    NaN
# 2                   4  Government Employee                    4.0
# 3                None             Business                    NaN
# 4                None             Business                    NaN
# ...               ...                  ...                    ...
# 486618           None             Labourer                    NaN
# 486619           None             Business                    NaN
# 486620           None               Farmer                    NaN
# 486621           None             Business                    NaN
# 486622           None             Business                    NaN
#
#        phone_number  name assumption_flag incomplete_flag
# 0              None  None        ORIGINAL               0
# 1              None  None        ORIGINAL               0
# 2              None  None        ORIGINAL               0
# 3              None  None        ORIGINAL               0
# 4              None  None      ASSUMPTION               0
# ...             ...   ...             ...             ...
# 486618         None  None        ORIGINAL               0
# 486619         None  None        ORIGINAL               0
# 486620         None  None        ORIGINAL               0
# 486621         None  None        ORIGINAL               0
# 486622         None  None        ORIGINAL               0
#
# [486623 rows x 19 columns]

# %%
# Move incomplete rows to a new table. They have already been flagged as incomplete

null_price_products = """CREATE TABLE null_price_products AS
SELECT *
FROM contracts
WHERE product IS NULL"""

cursor.execute(null_price_products)
conn.commit()

# %% [markdown]
# check null values in sales_person_id

# %%
"""Leave the null values as is as there are no csv files with sales person id to help us inpute the null values
Add missing sales person ID, to the incomplete flag"""

null_sales_person = """select * from contracts where sales_person_id is null 
"""
pd.read_sql(null_sales_person, conn)
# Out:
#       contractid sales_month    region                     product  \
# 0        2808119  2024-03-31  Southern                 Small Solar
# 1        2802742  2024-03-31  Southern  Large Solar - Generation 1
# 2        3399302  2025-02-28  Southern  Large Solar - Generation 1
# 3        2895662  2024-05-31  Southern  Large Solar - Generation 1
# 4        2999435  2024-07-31  Northern                 PAYGO_PHONE
# ...          ...         ...       ...                         ...
# 9715     3776685  2025-08-31  Northern              PAYGO_PORTABLE
# 9716     3792425  2025-09-30  Southern  Large Solar - Generation 1
# 9717     3805913  2025-09-30  Northern                 PAYGO_PHONE
# 9718     3808994  2025-09-30  Northern              PAYGO_PORTABLE
# 9719     3817012  2025-09-30  Northern                 Small Solar
#
#      sales_person_id contract_type  price_usd payment_frequency  perc_deposit  \
# 0               None      FINANCED      150.0             DAILY        0.0515
# 1               None          CASH      300.0              None        1.0000
# 2               None          CASH      300.0              None        1.0000
# 3               None      FINANCED      300.0             DAILY        0.0836
# 4               None      FINANCED      200.0             DAILY        0.0735
# ...              ...           ...        ...               ...           ...
# 9715            None      FINANCED      100.0             DAILY        0.0534
# 9716            None          CASH      300.0              None        1.0000
# 9717            None      FINANCED      200.0             DAILY        0.0959
# 9718            None      FINANCED      100.0             DAILY        0.0534
# 9719            None          CASH      150.0              None        1.0000
#
#       tenor_length  daily_amount_usd customer_gender household_size  \
# 0            450.0             0.309          Female           None
# 1              0.0               NaN            Male           None
# 2              0.0               NaN          Female           None
# 3            666.0             0.509            Male           None
# 4            400.0             0.463            Male           None
# ...            ...               ...             ...            ...
# 9715         399.0             0.237          Female           None
# 9716           0.0               NaN            Male           None
# 9717         400.0             0.452            Male           None
# 9718         399.0             0.237          Female           None
# 9719           0.0               NaN            Male           None
#
#      occupation  actual_household_size phone_number  name assumption_flag  \
# 0      Business                    NaN         None  None        ORIGINAL
# 1        Farmer                    NaN         None  None      ASSUMPTION
# 2        Farmer                    NaN         None  None      ASSUMPTION
# 3      Business                    NaN         None  None        ORIGINAL
# 4      Business                    NaN         None  None        ORIGINAL
# ...         ...                    ...          ...   ...             ...
# 9715      Other                    NaN         None  None        ORIGINAL
# 9716       None                    NaN         None  None      ASSUMPTION
# 9717   Business                    NaN         None  None        ORIGINAL
# 9718       None                    NaN         None  None        ORIGINAL
# 9719   Labourer                    NaN         None  None      ASSUMPTION
#
#      incomplete_flag
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 9715               1
# 9716               1
# 9717               1
# 9718               1
# 9719               1
#
# [9720 rows x 19 columns]

# %%
#save cleaned table as csv
df = pd.read_sql("SELECT * FROM contracts", conn)

df.to_csv("../cleaned_data/cleaned_contracts.csv", index=False)

# %%
df = pd.read_csv('../cleaned_data/cleaned_contracts.csv')
df.head()
# Out:
#    contractid sales_month   region      product  sales_person_id  \
# 0     3098268  2024-10-31  Western  Small Solar         154077.0
# 1     3554125  2025-04-30  Western  Small Solar         878345.0
# 2     2792627  2024-03-31  Western  Small Solar         648775.0
# 3     2869807  2024-05-31  Western  PAYGO_PHONE         328066.0
# 4     3674681  2025-06-30  Western  Small Solar         813534.0
#
#   contract_type  price_usd payment_frequency  perc_deposit  tenor_length  \
# 0      FINANCED      150.0            WEEKLY        0.0510         434.0
# 1      FINANCED      150.0            WEEKLY        0.0313         434.0
# 2      FINANCED      150.0            WEEKLY        0.0554         434.0
# 3      FINANCED      200.0            WEEKLY        0.1827         189.0
# 4      FINANCED      150.0            WEEKLY        0.0296         364.0
#
#    daily_amount_usd customer_gender household_size           occupation  \
# 0           0.32800            Male            NaN              Teacher
# 1           0.33500            Male            NaN              Teacher
# 2           0.32600            Male              4  Government Employee
# 3           0.86500            Male            NaN             Business
# 4           0.39989            Male            NaN             Business
#
#    actual_household_size  phone_number name assumption_flag  incomplete_flag
# 0                    NaN           NaN  NaN        ORIGINAL                0
# 1                    NaN           NaN  NaN        ORIGINAL                0
# 2                    4.0           NaN  NaN        ORIGINAL                0
# 3                    NaN           NaN  NaN        ORIGINAL                0
# 4                    NaN           NaN  NaN      ASSUMPTION                0

# %%
df.isna().sum()
# Out:
# contractid                    0
# sales_month                   0
# region                        0
# product                    2166
# sales_person_id            9720
# contract_type                 0
# price_usd                  2166
# payment_frequency         25352
# perc_deposit                  0
# tenor_length                  0
# daily_amount_usd          26808
# customer_gender               0
# household_size           476259
# occupation                59683
# actual_household_size    478315
# phone_number             484655
# name                     484612
# assumption_flag               0
# incomplete_flag               0
# dtype: int64
